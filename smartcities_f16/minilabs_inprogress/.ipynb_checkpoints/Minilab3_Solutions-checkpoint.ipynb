# %% [markdown]
# # Mini-lab 3 - Maps as a visualization tool

# %%
from datascience import *
import numpy as np
from geopy.geocoders import Nominatim

# %% [markdown]
# ### Geocoding
# Geocoding is the process of converting locations (such as address or points of interest) into geographic coordinates (such as lat, lon coordinates). The geopy.geocoders package gives us access to several geolocation API's (like google maps, Nominatim - open street maps API, bing maps API, etc.). The documentations for the geocoding package can be found here: https://geopy.readthedocs.io/en/1.10.0/.
#
#
# #### Geocoding example
# Below is an example of how the geocoding service works:

# %%
geolocator = Nominatim()
location = geolocator.geocode("175 5th Avenue NYC")
location
# Out:
# Location(Flatiron Building, 175, 5th Avenue, Flatiron, Manhattan, New York County, NYC, New York, 10010, United States of America, (40.7410861, -73.9896297241625, 0.0))

# %% [markdown]
# #### location properties

# %%
location.latitude, location.longitude, location.altitude, location.address,
# Out:
# (40.7410861,
#  -73.9896297241625,
#  0.0,
#  'Flatiron Building, 175, 5th Avenue, Flatiron, Manhattan, New York County, NYC, New York, 10010, United States of America')

# %% [markdown]
# #### Use the geolocater to find the lat lon coordinates for the Empire State Building in New York

# %%
# Your code here

# %% [markdown]
# # Creating maps
# If we generate a table with columns 'latitude', 'longitude', 'popup', and 'color'. We can generate maps with  markers from the table using the maps.Marker.map_table() method. See the example below. Click on the marker and the popup text should appear.

# %%
location = geolocator.geocode("175 5th Avenue NYC")
table = Table().with_columns(['latitude', [location.latitude],
                              'longitude', [location.longitude],
                              'popup', [location.address],
                              'color', ['red']])
table
# Out:
# latitude | longitude | popup                                                        | color
# 40.7411  | -73.9896  | Flatiron Building, 175, 5th Avenue, Flatiron, Manhattan, ... | red

# %%
maps.Marker.map_table(table)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_d121e618be6644d38dac6709d18e380d&quot; style=&quot;width: 960px; height: 500px&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
#           maxZoom: 17,
#           minZoom: 10,
#           attribution: 'Map data (c) <a href=&quot;http://openstreetmap.org&quot;>OpenStreetMap</a> contributors'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_d121e618be6644d38dac6709d18e380d', {
#                                        center:[40.7410861, -73.9896297242],
#                                        zoom: 12,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       //add the clustered markers to the group anyway
#       map.addLayer(clusteredmarkers);
#
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'red',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([40.7410861,
# 							-73.9896297242],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;Flatiron Building, 175, 5th Avenue, Flatiron, Manhattan, New York County, NYC, New York, 10010, United States of America&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       map.addLayer(marker_1)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    </script>
#
# </body>" style="width: 960px; height: 500px"; border: none"></iframe>

# %% [markdown]
# ### Add a row to the table for the empire state building
# The [Table.append()](http://data8.org/datascience/_autosummary/datascience.tables.Table.append.html?highlight=append#datascience.tables.Table.append) method may come in handy for adding a row.

# %%
# Your code here
location = geolocator.geocode("Empire State Building NYC")
table.append([location.latitude, location.longitude, location.address, 'blue'])
table
# Out:
# latitude | longitude | popup                                                        | color
# 40.7411  | -73.9896  | Flatiron Building, 175, 5th Avenue, Flatiron, Manhattan, ... | red
# 40.7484  | -73.9857  | Empire State Building, 350, 5th Avenue, Koreatown, Manha ... | blue

# %%
maps.Marker.map_table(table)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_3220fb23fbb64656b5ef3cb9b60d3cec&quot; style=&quot;width: 960px; height: 500px&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
#           maxZoom: 17,
#           minZoom: 10,
#           attribution: 'Map data (c) <a href=&quot;http://openstreetmap.org&quot;>OpenStreetMap</a> contributors'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_3220fb23fbb64656b5ef3cb9b60d3cec', {
#                                        center:[40.74475725, -73.987642122],
#                                        zoom: 14.0,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       //add the clustered markers to the group anyway
#       map.addLayer(clusteredmarkers);
#
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'red',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([40.7410861,
# 							-73.9896297242],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;Flatiron Building, 175, 5th Avenue, Flatiron, Manhattan, New York County, NYC, New York, 10010, United States of America&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       map.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([40.7484284,
# 							-73.9856545199],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;Empire State Building, 350, 5th Avenue, Koreatown, Manhattan, New York County, NYC, New York, 10018, United States of America&quot;);
#       marker_2._popup.options.maxWidth = 300;
#       map.addLayer(marker_2)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    </script>
#
# </body>" style="width: 960px; height: 500px"; border: none"></iframe>

# %%
# If we add a radius column, we can use circle markers instead of info markers
table['radius'] = 200
maps.Circle.map_table(table)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_c734cc0de1f04f8c8e8434e2fc7f03e8&quot; style=&quot;width: 960px; height: 500px&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
#           maxZoom: 17,
#           minZoom: 10,
#           attribution: 'Map data (c) <a href=&quot;http://openstreetmap.org&quot;>OpenStreetMap</a> contributors'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_c734cc0de1f04f8c8e8434e2fc7f03e8', {
#                                        center:[40.74475725, -73.987642122],
#                                        zoom: 14.0,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       //add the clustered markers to the group anyway
#       map.addLayer(clusteredmarkers);
#
#
#
#
#       var circle_1 = L.circle([40.7410861, -73.9896297242], 200, {
#                             color: 'None',
#                             fillColor: 'red',
#                             fillOpacity: 0.6
#                             });
#       circle_1.bindPopup(&quot;Flatiron Building, 175, 5th Avenue, Flatiron, Manhattan, New York County, NYC, New York, 10010, United States of America&quot;);
#       circle_1._popup.options.maxWidth = 300;
#       map.addLayer(circle_1)
#
#       var circle_2 = L.circle([40.7484284, -73.9856545199], 200, {
#                             color: 'None',
#                             fillColor: 'blue',
#                             fillOpacity: 0.6
#                             });
#       circle_2.bindPopup(&quot;Empire State Building, 350, 5th Avenue, Koreatown, Manhattan, New York County, NYC, New York, 10018, United States of America&quot;);
#       circle_2._popup.options.maxWidth = 300;
#       map.addLayer(circle_2)
#
#
#
#
#
#
#
#
#
#
#
#
#    </script>
#
# </body>" style="width: 960px; height: 500px"; border: none"></iframe>

# %% [markdown]
# ### Mapping utilities and services in San Francisco
# Mapping can be an important tool for visualizing spatial data. In the rest of this lab we will try to get more familiar with the mapping tools.
#
# #### Mapping firestations in SF
# 'firestations.csv' is a list of addresses of firestations in San Francisco.
#
# **Your tasks:**
# 1. Use the geolocater to find the lat, lon coordinates of each address, **I recommend adding ', San Francisco, CA' to each address before trying to geolocate it.** Add the latitude and longitude info to the firestations table.
# 2. Create a table that contains the columns ‘latitude’, ‘longitude’, ‘popup’, ‘color’, ‘radius’ with color = 'red', radius = 200, and popup = the Station # (from the firestation table).
# 3. Use maps.Circle.map_table(table) to create a map of the points

# %%
firestations = Table.read_table('firestations_v2.csv')
firestations
# Out:
# Station #  | Address
#  Station 1 | 935 Folsom Street
# Station 2  | 1340 Powell Street
# Station 3  | 1067 Post Street
#  Station 4 | 449 Mission Rock Street
#  Station 5 | 1301 Turk Street
#  Station 6 | 135 Sanchez Street
#  Station 7 | 2300 Folsom Street
#  Station 8 | 36 Bluxome Street
# Station 9  | 2245 Jerrold Avenue
# Station 10 | 655 Presidio Avenue
# ... (34 rows omitted)

# %%
my_locations = []
firestation_latitudes = []
firestation_longitudes = []

for address in firestations[1]:
    my_location = geolocator.geocode(address + ', San Francisco, CA')
    my_locations.append(my_location)
    firestation_latitudes.append(my_location.latitude)
    firestation_longitudes.append(my_location.longitude)
    print (address, my_location.latitude, my_location.longitude)
# Out:
# 935 Folsom Street 37.77933345 -122.4039941
# 1340 Powell Street 37.79701765 -122.409902899618
# 1067 Post Street  37.7866453 -122.419320375942
# 449 Mission Rock Street 37.7728017 -122.3891337
# 1301 Turk Street 37.78046345 -122.430732925358
# 135 Sanchez Street 37.7670862916667 -122.43103775
# 2300 Folsom Street 37.7601398 -122.415117753101
# 36 Bluxome Street 37.77726425 -122.396732414622
# 2245 Jerrold Avenue 37.74524125 -122.401260263639
# 655 Presidio Avenue 37.7856096 -122.446820711935
# 3880 26th Street 37.7487702 -122.426456734022
# 1145 Stanyan Street 37.76349705 -122.452642383039
# 530 Sansome Street 37.7955437 -122.401385404319
# 551 26th Avenue 37.7790025 -122.486039248477
# 1000 Ocean Avenue 37.7234515 -122.452889586526
# 2251 Greenwich Street 37.79866695 -122.436734299265
# 1295 Shafter Avenue 37.72751265 -122.385043629742
# 1935 32nd Avenue 37.7509884 -122.4905546
# 390 Buckingham Way 37.72784295 -122.478905099303
# 285 Olympia Way 37.7513090950274 -122.456090411846
# 1443 Grove Street 37.7755401428571 -122.440366571429
# 1290 16th Avenue 37.76398385 -122.473689477578
# 1348 45th Avenue 37.76141855 -122.504636668136
# 100 Hoffman Avenue 37.753175 -122.440944
# 3305 3rd Street 37.7866798 -122.4025728
# 80 Digby Street 37.740138532591 -122.433425995802
# 1814 Stockton Street 37.7880412 -122.4066888
# 299 Vermont Street 37.7661604 -122.40439025
# 441 12th Avenue 37.77985115 -122.471206675916
# 194 Park Street 37.7364685510204 -122.421249428571
# 8 Capitol Avenue 37.710962125 -122.4588971875
# 499 41st Avenue 37.77947855 -122.502551216065
# Pier 22 1/2 37.7904092 -122.388269194721
# 109 Oak Street 37.774983 -122.421238652203
# 798 Wisconsin Street 37.75740585 -122.399234848483
# 2150 California Street 37.7854082 -122.4613835
# 1091 Portola Drive 37.7406436039956 -122.457920342755
# 2155 18th Avenue 37.7636193 -122.4760745
# 1325 Leavenworth Street 37.7933180769231 -122.41628
# 2430 San Bruno Avenue 37.731690375 -122.4053925
# 720 Moscow Street 37.7162557142857 -122.431528918367
# 1298 Girard Street 37.716665 -122.400266
# 1415 Evans Avenue 37.7409845714286 -122.385163285714
# 218 Lincoln Blvd 37.8066927 -122.4735086

# %%
from datasciece import *
t = Table().with_columns([A:[1,2,3],
                          B:[2,3,4]])

# %%
geolocator.geocode(address +', San Francisco, CA')
# Out:
# Location(Lincoln Boulevard, SF, California, 94129, United States of America, (37.8066927, -122.4735086, 0.0))

# %%
firestations['latitude'] = firestation_latitudes
firestations['longitude'] = firestation_longitudes
table = firestations.select(['latitude','longitude','Station #'])
table = table.relabel('Station #', 'popup')
table['color'] = 'red'
table['radius'] = 200
maps.Circle.map_table(table)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_86cf4491c89245d4ad1e13c91d274f65&quot; style=&quot;width: 960px; height: 500px&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
#           maxZoom: 17,
#           minZoom: 9.0,
#           attribution: 'Map data (c) <a href=&quot;http://openstreetmap.org&quot;>OpenStreetMap</a> contributors'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_86cf4491c89245d4ad1e13c91d274f65', {
#                                        center:[37.7588274125, -122.444840149],
#                                        zoom: 11.0,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       //add the clustered markers to the group anyway
#       map.addLayer(clusteredmarkers);
#
#
#
#
#       var circle_1 = L.circle([37.77933345, -122.4039941], 200, {
#                             color: 'None',
#                             fillColor: 'red',
#                             fillOpacity: 0.6
#                             });
#       circle_1.bindPopup(&quot; Station 1&quot;);
#       circle_1._popup.options.maxWidth = 300;
#       map.addLayer(circle_1)
#
#       var circle_2 = L.circle([37.79701765, -122.4099029], 200, {
#                             color: 'None',
#                             fillColor: 'red',
#                             fillOpacity: 0.6
#                             });
#       circle_2.bindPopup(&quot;Station 2&quot;);
#       circle_2._popup.options.maxWidth = 300;
#       map.addLayer(circle_2)
#
#       var circle_3 = L.circle([37.7866453, -122.419320376], 200, {
#                             color: 'None',
#                             fillColor: 'red',
#                             fillOpacity: 0.6
#                             });
#       circle_3.bindPopup(&quot;Station 3&quot;);
#       circle_3._popup.options.maxWidth = 300;
#       map.addLayer(circle_3)
#
#       var circle_4 = L.circle([37.7728017, -122.3891337], 200, {
#                             color: 'None',
#                             fillColor: 'red',
#                             fillOpacity: 0.6
#                             });
#       circle_4.bindPopup(&quot; Station 4&quot;);
#       circle_4._popup.options.maxWidth = 300;
#       map.addLayer(circle_4)
#
#       var circle_5 = L.circle([37.78046345, -122.430732925], 200, {
#                             color: 'None',
#                             fillColor: 'red',
#                             fillOpacity: 0.6
#                             });
#       circle_5.bindPopup(&quot; Station 5&quot;);
#       circle_5._popup.options.maxWidth = 300;
#       map.addLayer(circle_5)
#
#       var circle_6 = L.circle([37.7670862917, -122.43103775], 200, {
#                             color: 'None',
#                             fillColor: 'red',
#                             fillOpacity: 0.6
#                             });
#       circle_6.bindPopup(&quot; Station 6&quot;);
#       circle_6._popup.options.maxWidth = 300;
#       map.addLayer(circle_6)
#
#       var circle_7 = L.circle([37.7601398, -122.415117753], 200, {
#                             color: 'None',
#                             fillColor: 'red',
#                             fillOpacity: 0.6
#                             });
#       circle_7.bindPopup(&quot; Station 7&quot;);
#       circle_7._popup.options.maxWidth = 300;
#       map.addLayer(circle_7)
#
#       var circle_8 = L.circle([37.77726425, -122.396732415], 200, {
#                             color: 'None',
#                             fillColor: 'red',
#                             fillOpacity: 0.6
#                             });
#       circle_8.bindPopup(&quot; Station 8&quot;);
#       circle_8._popup.options.maxWidth = 300;
#       map.addLayer(circle_8)
#
#       var circle_9 = L.circle([37.74524125, -122.401260264], 200, {
#                             color: 'None',
#                             fillColor: 'red',
#                             fillOpacity: 0.6
#                             });
#       circle_9.bindPopup(&quot;Station 9&quot;);
#       circle_9._popup.options.maxWidth = 300;
#       map.addLayer(circle_9)
#
#       var circle_10 = L.circle([37.7856096, -122.446820712], 200, {
#                             color: 'None',
#                             fillColor: 'red',
#                             fillOpacity: 0.6
#                             });
#       circle_10.bindPopup(&quot;Station 10&quot;);
#       circle_10._popup.options.maxWidth = 300;
#       map.addLayer(circle_10)
#
#       var circle_11 = L.circle([37.7487702, -122.426456734], 200, {
#                             color: 'None',
#                             fillColor: 'red',
#                             fillOpacity: 0.6
#                             });
#       circle_11.bindPopup(&quot;Station 11&quot;);
#       circle_11._popup.options.maxWidth = 300;
#       map.addLayer(circle_11)
#
#       var circle_12 = L.circle([37.76349705, -122.452642383], 200, {
#                             color: 'None',
#                             fillColor: 'red'
