# %%
# %matplotlib inline
from datascience import *
import numpy as np
import matplotlib.pyplot as plt

# %%
ev_data = Table.read_table('data/Atlanta-Mobility-And-Simulated-Charging-Events.csv')

# %%
ev_data
# Out:
# driver | day  | time    | vehicle.type | distance | scheduled | begin.soc | end.soc   | elec.used | gas.used | end.time | timestamp     | charger.id | charger.level | duration  | energy  | after.end.charge | charging.on.whim | time.until.depart
# 1      | 1    | 10.8067 | leaf         | 9.68516  | 1         | 1         | 0.853117  | 3.52518   | 0        | 11.0925  | 4/21/11 10:48 | nan        | nan           | nan       | nan     | nan              | nan              | nan
# 1      | 1    | 11.3419 | leaf         | 16.1977  | 1         | 0.853117  | 0.607467  | 5.8956    | 0        | 11.7563  | 4/21/11 11:20 | nan        | nan           | nan       | nan     | nan              | nan              | nan
# 1      | 1    | 12.7422 | leaf         | 16.1977  | 1         | 0.607467  | 0.361817  | 5.8956    | 0        | 13.1566  | 4/21/11 12:44 | nan        | nan           | nan       | nan     | nan              | nan              | nan
# ...

# %%
# charge = 
charge = ev_data.where(ev_data['energy']>0)
# charge['time']+charge['duration']
charge['duration']
# charge['hour'] = np.floor(charge['time'])

#if this then the energy = energy
np.floor(charge['time']) == np.floor(charge['time']+charge['duration'])

# if not then energy for hr 1.
np.floor(charge['time']) != np.floor(charge['time']+charge['duration'])


# (ev_data['energy'][5])>0
# ev_data.select(['time','end.time','energy', 'elec.used'])
# Out:
# array([False,  True, False, ...,  True,  True,  True], dtype=bool)

# %%
charge['end'] = charge['time']+charge['duration']

#1st hour %
charge['first_hr_dur'] = (np.minimum(charge['end'], np.ceil(charge['time']))-charge['time']) #/charge['duration']*elec.used

hour = np.floor(charge['time'])%24
print (len(hour))
new = Table(['hour', 'energy'])
energy = charge['first_hr_dur']/charge['duration']*charge['energy']

counted = charge['first_hr_dur']

for i in range(5):
    rest = (charge['duration'] - counted)
    rest = np.where(abs(rest)<1e-6, 0,rest)
#     print (rest)

    charge2 = charge.where(rest)
    charge2['rest'] = rest[np.where(rest)]
    hour = np.append(hour, (np.floor(charge2['time'])+i)%24)
    time_hr = np.where(charge2['rest']>1, 1, charge2['rest']) 
    energy = np.append(energy, time_hr/charge2['duration']*charge2['energy'])
    counted = counted + np.where(rest>1, 1, rest)
    
new['hour'] = hour
new['energy'] = energy

len(hour)
# np.where(abs(charge['duration']-counted)<1e-6,0, abs(charge['duration']-counted))
# len(hour)
# np.where(rest, np.floor(charge['time']+1), 0)
# np.where(rest, np.minimum(rest,1),0)



# charge['sec_hr_dur'] = np.where(rest>1, 1, rest)

# rest = rest - charge['sec_hr_dur']
# charge['third_hr_dur'] = np.where(rest>1, 1, rest)
# rest = rest - charge['third_hr_dur']

# charge['fourth_hr_dur'] = np.where(rest>1, 1, rest)
# rest = rest - charge['fourth_hr_dur']

# charge['fifth_hr_dur'] = np.where(rest>1, 1, rest)
# rest = rest - charge['fifth_hr_dur']

# charge.group(np.floor(charge['time']), np.sum)

# # sec_hr_dur 


# #2nd hour %
# # sec_hr = np.where(np.floor(charge['time']) != np.floor(charge['end']),(charge['end'] -np.floor(charge['end'])
# #                                                              )/charge['duration'], 0)

# # np.where(charge['duration']>2)



# # np.floor(charge['time']) != np.floor(charge['time']+charge['duration'])
# Out:
# 10425
# 19878

# %%
rest[np.where(rest)]
# Out:
# array([], dtype=float64)

# %%
grp = new.group('hour', np.mean)

# %%
plt.plot(grp['hour'], grp['energy mean'])

# %%
charge['strt_hr'] = np.floor(charge['time'])%24
grp2 = charge.group('strt_hr', np.sum)
plt.plot(grp2['strt_hr']%24, grp2['energy sum'])

# %%
new = []

rest = charge['duration']
start = charge['time']
hour = np.floor(charge['time'])
for i in range(len(charge['time'])):
    
    while rest[i]>1e-6:
        if max(hour[i], charge['time'][i])+rest[i] < hour[i]+1:
            time_in_hr = rest[i]

        else:
            #finishes after the hour, only count up to the hour
            time_in_hr = hour[i]+1 - max(hour[i], charge['time'][i])
            hour[i]+=1
            rest[i] = rest[i]-time_in_hr
        
        print rest[i], time_in_hr
        energy_in_hr = time_in_hr/charge['duration'][i]
        new.append([hour[i], energy_in_hr])
        
    
    while (rest[i])>1e-6:
        if hour[i] == np.floor(charge['end']):
# Out:
# 0.074736588
# 0.364190426
# 0.00077322
# 0.009310559
# 0.003201636
# 0.003201636
# 0.009310559
# 0.009310559
# 2.04808667
# 0.230079112
# 0.311492126
# 0.009310559
# 0.010999128
# 1.174971426
# 1.716151367
# 2.145630806
# 0.133409022
# 2.443424094
# 0.13053198
# 2.443424094
# 0.088960294
# 2.128487074
# 0.13053198
# 2.443424094
# 2.90004328
# 0.019716018
# 0.005657837
# 0.369326938
# 0.035606227
# 0.038334522
# 0.146015753
# 0.000746835
# 0.152125934
# 0.542927135
# 0.475952899
# 0.118376205
# 0.045301371
# 1.0
# 0.076768802
# 0.000746835
# 1.699494124
# 0.223897843
# 2.757639443
# 0.293851269
# 0.011902588
# 0.003032051
# 0.003032051
# 0.09413911
# 0.1602391
# 2.771810612
# 0.219984196
# 0.13098347
# 3.191250011
# 2.802691964
# 0.177770291
# 0.118988653
# 0.047204958
# 0.339978586
# 2.392442327
# 0.517865114
# 0.00514397
# 0.344367604
# 3.435746864
# 0.37099745
# 0.092240974
# 1.0
# 2.232578804
# 1.937858758
# 0.19819953
# 0.279701402
# 0.317661015
# 1.0
# 0.150632035
# 2.024493464
# ...
